# %%
# https://www.linkedin.com/company/bcrpoficial/
# https://web.facebook.com/bcrpoficial
# https://www.instagram.com/bcrpoficial/
# https://twitter.com/bcrpoficial

# %%
#!pip install -r ../requirements.txt

# %% [markdown]
# ## Post Hashtag bancocentral

# %%
# -*- coding: utf-8 -*-
"""
Autor : MiltonCalamaro
"""
import datetime as dt
from itertools import dropwhile, takewhile
import instaloader
import pandas as pd
import re
import json
import os
import logging
import argparse
logging.basicConfig(level = logging.INFO)
logger = logging.getLogger('__instagram__')

def get_posts_hashtag(since, until, hashtag):
    L = instaloader.Instaloader( # Main Class info: https://instaloader.github.io/as-module.html#instaloader-main-class
        download_pictures=False,
        download_videos=False, 
        download_video_thumbnails=False,
        compress_json=False, 
        download_geotags=False, 
        post_metadata_txt_pattern="", 
        max_connection_attempts=0,
        download_comments=True,
        save_metadata = False,
        filename_pattern = '{mediaid}'
    )
    L.login('milton_calamaro', 'xxxxxxxxxxx')
    posts = instaloader.NodeIterator(
        L.context, "9b498c08113f1e09617a1703c22b2f32",
        lambda d: d['data']['hashtag']['edge_hashtag_to_media'],
        lambda n: instaloader.Post(L.context, n),
        {'tag_name': hashtag},
        f"https://www.instagram.com/explore/tags/{hashtag}/"
    )
    print("capturing posts from: "+str(since)+" to: "+str(until))
    since = dt.datetime.strptime(since, "%Y-%m-%d %H:%M:%S")
    until = dt.datetime.strptime(until, "%Y-%m-%d %H:%M:%S")
    list_post = []
    for post in posts:#takewhile(lambda p: p.date >= UNTIL, dropwhile(lambda p: p.date >= SINCE, posts)):
        dict_post = {}
        dict_post['post_id'] = post.mediaid
        dict_post['date'] = post.date_local
        dict_post['user_id'] = post.owner_id
        dict_post['user_name'] = post.owner_username
        dict_post['text'] = post.caption
        dict_post['post_url'] = f'https://www.instagram.com/p/{post.shortcode}/'
        dict_post['post_type'] = post.typename
        dict_post['hashtags'] = post.caption_hashtags
        dict_post['mentions'] = post.tagged_users
        dict_post['replies'] = post.comments
        dict_post['likes'] = post.likes
        dict_post['url_picture'] = post.url
        dict_post['location_id'] =  post.__dict__['_full_metadata_dict']['location']['id'] if post.__dict__['_full_metadata_dict']['location'] else ''
        dict_post['location_name'] = post.__dict__['_full_metadata_dict']['location']['name'] if post.__dict__['_full_metadata_dict']['location'] else ''
#         dict_post['location'] = post.location
        dict_post['is_video'] = post.is_video
        dict_post['video_duration'] = post.video_duration
        dict_post['video_url'] = post.video_url
        dict_post['video_view'] = post.video_view_count
        if since>post.date_local:
            break
        list_post.append(dict_post)
        logger.info(' {} | {} | {}'.format(post.date_local, post.mediaid, post.caption.replace('\n', ' ')))
        L.download_post(post, target=f'#{hashtag}')
    return pd.DataFrame(list_post)
# Out:
# C:\Users\usuario\anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)

# %%
hashtag = 'bbva'
since = '2021-09-26 10:00:00'
until = '2021-09-26 15:00:00'
df_posts_hashtag = get_posts_hashtag(since, until, hashtag)
��🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩🤩 #JarochitaCumbres: Av. Paseo de los Leones 100 Col. Cumbres 7 mo. Sector. Al lado del rest. #LosFresnos en la Plaza detrás del #BBVA.  ☎ 818148 4969 (8 am a 9 pm) #JarochitaTec: Av. del Estado 386 esq. Río Pánuco Col. Tecnológico.  ☎ 818244 5385 (8 am a 9 pm) www.lajarochita.mx
# INFO:__instagram__: 2021-09-26 10:08:03 | 2671342668537265107 | Más entregas del día de ayer. 🤗😎  ¡Felicidades por tu espectacular Rouser NS 200, 0KM!  ¡Muchas gracias por elegirnos! 🙂 ---------------------- 👉No sigas dependiendo del transporte público y subite a tu primera Rouser y pagala en hasta18 cuotas FIJAS, SIN INTERÉS Y EN PESOS! SOLO CON TU DNI‼️💸💸💸💸  ¿Qué estás esperando para tener la tuya? 🏍️🏍️🏍️🏍️  ¡Te esperamos!😎 ................................................. 📲 Consultanos! Tu pregunta no es molestia! Estamos para asesorarte: 11 6723-8573 (general) 11 3679-3514 (Fedra) 11 2297-8936 (Leandro)  ☎️ 4276-0909 ☎️ 4267-8496 ....................................................... #solocondni #motocicletas #motorcycle #MOTO #promo #lanus #lanus #valentinalsina #gerli #remediosdeescalada #avellaneda #lomasdezamora #Banfield #Temperley #zonasurbuenosaires #bajaj #bajajargentina #bajajpulsar #ahora12 #ahora18 #rouser #rouserns200 #ns200 #ns #ns200 #bajajns200 #bajajrouser #rouser200ns #bbva

# %% [markdown]
# ## Posts profile bcrpoficial

# %%
def get_posts_profile(since, until, username):
    L = instaloader.Instaloader( # Main Class info: https://instaloader.github.io/as-module.html#instaloader-main-class
        download_pictures=False,
        download_videos=False, 
        download_video_thumbnails=False,
        compress_json=False, 
        download_geotags=False, 
        post_metadata_txt_pattern="", 
        max_connection_attempts=0,
        download_comments=True,
        save_metadata = False,
        filename_pattern = '{mediaid}'
    )
    L.login('milton_calamaro', 'xxxxxxxxxxx')
    posts = instaloader.Profile.from_username(L.context, username).get_posts()
    SINCE = dt.datetime.strptime(until, "%Y-%m-%d %H:%M:%S") + dt.timedelta(hours=+5)
    UNTIL = dt.datetime.strptime(since, "%Y-%m-%d %H:%M:%S") + dt.timedelta(hours=+5)
    list_post = []
    for post in takewhile(lambda p: p.date >= UNTIL, dropwhile(lambda p: p.date >= SINCE, posts)):
        dict_post = {}
        dict_post['post_id'] = post.mediaid
        dict_post['date'] = post.date_local
        dict_post['user_id'] = post.owner_id
        dict_post['user_name'] = post.owner_username
        dict_post['text'] = post.caption
        dict_post['post_url'] = f'https://www.instagram.com/p/{post.shortcode}/'
        dict_post['post_type'] = post.typename
        dict_post['hashtags'] = post.caption_hashtags
        dict_post['mentions'] = post.tagged_users
        dict_post['replies'] = post.comments
        dict_post['likes'] = post.likes
        dict_post['url_picture'] = post.url
        dict_post['location'] = post.__dict__['_node']['location']
        dict_post['is_video'] = post.is_video
        dict_post['video_duration'] = post.video_duration
        dict_post['video_url'] = post.video_url
        dict_post['video_view'] = post.video_view_count
        list_post.append(dict_post)
        logger.info(' {} | {} | {}'.format(post.date_local, post.mediaid, post.caption.replace('\n', ' ')))
        L.download_post(post, target=f'{username}')
    return pd.DataFrame(list_post)

# %%
username = 'bbva'
since = '2021-09-20 10:00:00'
until = '2021-09-26 15:00:00'
df_posts_profile = get_posts_profile(since, until, username)
# Out:
# INFO:__instagram__: 2021-09-24 04:26:36 | 2669720942272307660 | 𝑹𝒆𝒄𝒆𝒕𝒂 𝒅𝒆 𝒄𝒍𝒂𝒇𝒐𝒖𝒕𝒊𝒔 𝒅𝒆 𝒑𝒆𝒓𝒂𝒔 𝒂𝒍 𝒗𝒊𝒏𝒐 𝒄𝒐𝒏 𝒒𝒖𝒆𝒔𝒐 𝒄𝒂𝒃𝒓𝒂𝒍𝒆𝒔 𝒅𝒆 𝑱𝒐𝒓𝒅𝒊 𝑹𝒐𝒄𝒂 🍽 de @CellerRocaBBVA. "Una receta muy sencilla, muy de hacer en casa, muy posible”. Tienes las instrucciones completas de la receta en #LinkInBio   Jordi Roca introduces us to his clafoutis tart with pears in wine and cabrales cheese: "We're going to make a recipe that's very simple, easy to make at home, and feasible."   #Recetas #ElCellerdeCanRoca #Gastronomía #recetasfáciles #foodie #foodporn #foods #gastronomy #igfood #igersfood #cellercanroca #JordiRoca #hermanosRoca #RocaBrothers #cellerdecanroca #gastronomíasostenible #gastronomiasostenible #sustainablefood #clafoutistart #clafoutis #pera #postre #perasalvino #quesocabrales #cabrales
# comments
# INFO:__instagram__: 2021-09-22 05:26:49 | 2668302017694969041 | BBVA lanza en España una calculadora de huella de carbono. Este nuevo servicio pretende concienciar sobre el impacto que cada persona tiene sobre el medioambiente. ¿Sabes cuál es tu huella de carbono?  BBVA launches a carbon footprint calculator in Spain. This new service aims to raise awareness of the impact that each person has on the environment. Do you know what your carbon footprint is?  #HuellasGigantes #LaHuellaQueDejas #MásVerdeEInclusivo #HuellaDeCarbono #Sostenibilidad #GreenerAndMoreInclusive #Sustainability #CarbonFootprint
# comments
# INFO:__instagram__: 2021-09-20 10:46:46 | 2667013502153960796 | ¿Y tú? ¿Qué haces con la #ropa que ya no utilizas? El mercado de segunda mano es una opción, pero tenemos que ir un paso más allá si lo que queremos es lograr un mundo #MásVerdeEInclusivo para todos. Recoger, tratar y reciclar prendas usadas es más difícil de lo que parece pero será necesario si queremos evitar el enorme impacto ambiental del sector y apostar por la #sostenibilidad. Te contamos el proceso y los avances en este carrusel, ¡desliza ya! Y si quieres conocer empresas y cómo sumar a esta causa ve al enlace de nuestra bio.  And you? What do you do with the #clothes that you no longer use? The second-hand market is an option, but we have to go one step further if what we want is to achieve a #GreenerAndMoreInclusive world for everyone. Collecting, treating and recycling used garments is more difficult than it seems but it will be necessary if we want to avoid the enormous environmental impact of the sector and bet on #sustainability. Find out more about the process in this carousel, slide now! And if you want to know companies and how to join this cause go to the link in our bio.
# comments

# %%
df_posts_profile
# Out:
#                post_id                date     user_id user_name  \
# 0  2669720942272307660 2021-09-24 04:26:36  1793431643      bbva
# 1  2668302017694969041 2021-09-22 05:26:49  1793431643      bbva
# 2  2667013502153960796 2021-09-20 10:46:46  1793431643      bbva
#
#                                                 text  \
# 0  𝑹𝒆𝒄𝒆𝒕𝒂 𝒅𝒆 𝒄𝒍𝒂𝒇𝒐𝒖𝒕𝒊𝒔 𝒅𝒆 𝒑𝒆𝒓𝒂𝒔 𝒂𝒍 𝒗𝒊𝒏𝒐 𝒄𝒐𝒏 𝒒𝒖𝒆𝒔𝒐...
# 1  BBVA lanza en España una calculadora de huella...
# 2  ¿Y tú? ¿Qué haces con la #ropa que ya no utili...
#
#                                    post_url     post_type  \
# 0  https://www.instagram.com/p/CUMwQ1dj-HM/    GraphVideo
# 1  https://www.instagram.com/p/CUHtow-KqzR/    GraphImage
# 2  https://www.instagram.com/p/CUDIqZXDq1c/  GraphSidecar
#
#                                             hashtags          mentions  \
# 0  [linkinbio, recetas, elcellerdecanroca, gastro...  [cellerrocabbva]
# 1  [huellasgigantes, lahuellaquedejas, másverdeei...                []
# 2  [ropa, másverdeeinclusivo, sostenibilidad, clo...                []
#
#    replies  likes                                        url_picture location  \
# 0       21    144  https://instagram.faqp2-2.fna.fbcdn.net/v/t51....     None
# 1        5    149  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....     None
# 2       16     85  https://instagram.faqp2-2.fna.fbcdn.net/v/t51....     None
#
#    is_video  video_duration  \
# 0      True          58.966
# 1     False             NaN
# 2     False             NaN
#
#                                            video_url  video_view
# 0  https://instagram.faqp2-3.fna.fbcdn.net/v/t50....      1732.0
# 1                                               None         NaN
# 2                                               None         NaN

# %% [markdown]
# ## Get post's comment

# %%
def get_fields_comment(comment, parent_id, root_id):
    try: 
        is_verified = comment['owner']['is_verified']
    except:
        is_verified = ''
    dict_comment = {'comment_id':comment['id'], 
                    'created_at':dt.datetime.fromtimestamp(comment['created_at']),
                    'text':comment['text'],
                    'user_id':comment['owner']['id'],
                    'is_verified':is_verified,
                    'picture_url':comment['owner']['profile_pic_url'],
                    'user_name':comment['owner']['username'],
                    'likes_count':comment['likes_count'],
                    'parent_id':parent_id,
                    'root_id':root_id
                   }
    logger.info(' {} | {} | {}'.format(dict_comment['created_at'], dict_comment['comment_id'], dict_comment['text'].replace('\n', ' ')))
    return dict_comment

def get_list_comments(filename):
    root_id = re.sub(r'\D+', '', filename)
    with open(filename) as fp:
        data = json.load(fp)
    list_comment = []
    for comment in data:
        list_comment.append(get_fields_comment(comment, root_id, root_id))
        if comment['answers']:
            for replies in comment['answers']:
                list_comment.append(get_fields_comment(replies, comment['id'], root_id))
    return list_comment

# %%
logger.info("NOW, SCRAPPER COMMENTS OF THE POSTS")
list_comment = []
for filename in os.listdir(f'#{hashtag}'):
    list_comment.extend(get_list_comments(f'#{hashtag}/{filename}'))
df_comments = pd.DataFrame(list_comment)
# Out:
# INFO:__instagram__:NOW, SCRAPPER COMMENTS OF THE POSTS
# INFO:__instagram__: 2021-05-25 15:16:58 | 17902345270886529 | 😍😍😍
# INFO:__instagram__: 2021-05-25 15:26:01 | 17902372762948208 | @quesecuecepormadrid 🙌
# INFO:__instagram__: 2021-05-25 13:06:08 | 17904711757918343 | Me encanto la foto!
# INFO:__instagram__: 2021-05-25 13:15:07 | 17928894802574327 | @jessicacanaltravel Gracias! Me alegro que guste a pesar del reflejo del cristal 😅
# INFO:__instagram__: 2021-05-25 13:16:57 | 17880700676249024 | @jessicacanaltravel Sobre todo, lo amateur de la misma 👏
# INFO:__instagram__: 2021-05-25 13:15:47 | 17854298918565948 | @emauss86 Don’t worry, le da personalidad a la foto ☺️
# INFO:__instagram__: 2021-05-25 13:00:07 | 17969549032402580 | Love this one ❤️
# INFO:__instagram__: 2021-05-25 13:13:35 | 18113923624231249 | @snapf21 i’m glad for that 🙌
# 2    17904711757918343 2021-05-25 13:06:08
# 3    17928894802574327 2021-05-25 13:15:07
# 4    17880700676249024 2021-05-25 13:16:57
# ..                 ...                 ...
# 310  17947848880516985 2021-09-25 21:07:23
# 311  18259566877035789 2021-09-25 20:01:39
# 312  18261055162022732 2021-09-26 11:30:00
# 313  17890089311456524 2021-09-26 09:05:38
# 314  17921678503812692 2021-09-26 10:08:08
#
#                                                   text      user_id  \
# 0                                                  😍😍😍  42101334749
# 1                               @quesecuecepormadrid 🙌    800600528
# 2                                  Me encanto la foto!  41366474425
# 3    @jessicacanaltravel Gracias! Me alegro que gus...    800600528
# 4    @jessicacanaltravel Sobre todo, lo amateur de ...    800600528
# ..                                                 ...          ...
# 310                             Buenas q precio tiene?  42044175210
# 311                        Hola quería saber más infoo   3132387701
# 312                     @matt_correa_21 Info enviada 😃   7725865717
# 313                                Eres una máquina 👏👏  17305778782
# 314                                           How tf 😂   1421785021
#
#      is_verified                                        picture_url  \
# 0          False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 1          False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 2          False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 3          False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 4          False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# ..           ...                                                ...
# 310        False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 311        False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 312        False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 313        False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 314        False  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
#
#                user_name  likes_count            parent_id  \
# 0    quesecuecepormadrid            1  2581530201261140860
# 1               emauss86            1    17902345270886529
# 2     jessicacanaltravel            2  2581530201261140860
# 3               emauss86            1    17904711757918343
# 4               emauss86            1    17904711757918343
# ..                   ...          ...                  ...
# 310        alecena822020            0  2670826211466197996
# 311       matt_correa_21            0  2670909723999488962
# 312       motobanfieldok            0    18259566877035789
# 313         elteacher_68            1  2671306670883336575
# 314        wesleygraham_            1  2671332266255576284
#
#                  root_id
# 0    2581530201261140860
# 1    2581530201261140860
# 2    2581530201261140860
# 3    2581530201261140860
# 4    2581530201261140860
# ..                   ...
# 310  2670826211466197996
# 311  2670909723999488962
# 312  2670909723999488962
# 313  2671306670883336575
# 314  2671332266255576284
#
# [315 rows x 10 columns]

# %% [markdown]
# ## Get user_info

# %%
def get_user_info(username):
    L = instaloader.Instaloader( # Main Class info: https://instaloader.github.io/as-module.html#instaloader-main-class
        download_pictures=False,
        download_videos=False, 
        download_video_thumbnails=False,
        compress_json=False, 
        download_geotags=False, 
        post_metadata_txt_pattern=None, 
        max_connection_attempts=2,
        download_comments=False,
    )
    dict_user_info = {}
    profile = instaloader.Profile.from_username(L.context, username)
#     profile = instaloader.Profile.from_id(L.context, username)
    dict_user_info['user_id'] = profile.userid
    dict_user_info['user_name'] = profile.username
    dict_user_info['user_fullname'] = profile.full_name
    dict_user_info['profile_url'] = f'https://www.instagram.com/{profile.username}' 
    dict_user_info['picture_url'] = profile.profile_pic_url 
    dict_user_info['biography'] = profile.biography
    dict_user_info['followees_count'] = profile.followees
    dict_user_info['followers_count'] = profile.followers 
    dict_user_info['highlight_count'] = profile.__dict__['_node']['highlight_reel_count']
    dict_user_info['post_count'] = profile.mediacount 
    dict_user_info['igtv_count'] = profile.igtvcount 
    dict_user_info['is_verified'] = profile.is_verified 
    dict_user_info['is_private'] = profile.is_private
    dict_user_info['is_business_account'] = profile.is_business_account
    dict_user_info['business_category'] = profile.business_category_name
    dict_user_info['business_email'] = profile.__dict__['_node']['business_email']
    dict_user_info['category_enum'] = profile.__dict__['_node']['category_enum']
    dict_user_info['external_url'] = profile.external_url
    logger.info(f' {profile.userid} | {profile.username} | {profile.full_name}')
    return dict_user_info

# %%
list_user_info = []
for username in set(df_posts_hashtag['user_name']):
    list_user_info.append(get_user_info(username))
    df_user_info = pd.DataFrame(list_user_info)
# Out:
# INFO:__instagram__: 1755647939 | brokers_financieros | BrokersFinancieros
# INFO:__instagram__: 190635007 | actividadpayonormal | Actividad  Payonormal.
# INFO:__instagram__: 3084209452 | lajarochitamty | La Jarochita
# INFO:__instagram__: 2123157311 | we.are.futbol | Football • Futbol • Soccer
# INFO:__instagram__: 47065897466 | nadyacabreraprensa | Nadya Cabrera Prensa
# INFO:__instagram__: 7725865717 | motobanfieldok | MotoBanfield

# %%
df_user_info
# Out:
#        user_id            user_name               user_fullname  \
# 0   1755647939  brokers_financieros          BrokersFinancieros
# 1    190635007  actividadpayonormal      Actividad  Payonormal.
# 2   3084209452       lajarochitamty                La Jarochita
# 3   2123157311        we.are.futbol  Football • Futbol • Soccer
# 4  47065897466   nadyacabreraprensa        Nadya Cabrera Prensa
# 5   7725865717       motobanfieldok                MotoBanfield
#
#                                      profile_url  \
# 0  https://www.instagram.com/brokers_financieros
# 1  https://www.instagram.com/actividadpayonormal
# 2       https://www.instagram.com/lajarochitamty
# 3        https://www.instagram.com/we.are.futbol
# 4   https://www.instagram.com/nadyacabreraprensa
# 5       https://www.instagram.com/motobanfieldok
#
#                                          picture_url  \
# 0  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 1  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 2  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 3  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 4  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
# 5  https://instagram.faqp2-1.fna.fbcdn.net/v/t51....
#
#                                            biography  followees_count  \
# 0  Empresa facilitadora de:\n👉Crédito Hipotecario...               60
# 1  Tengo una novia que me muerde y una perrita qu...              526
# 2  Restaurante con alma de pirata y sazón de casa...              131
# 3  🔸Thanks 67k ❤⚽️\n🔹Goal 100k...? 🔥\n🔸Send Video...              284
# 4  Agente de prensa en @gonnagoprod @operalaplata...              273
# 5  BIENVENIDOS A MOTOBANFIELD\nLíderes en comerci...              507
#
#    followers_count  highlight_count  post_count  igtv_count  is_verified  \
# 0             2313               31         779          51        False
# 1              710                6         836           0        False
# 2             5768                0        4582          11        False
# 3            67559                5        2998           1        False
# 4              490                0         196           0        False
# 5             2169                8         340           0        False
#
#    is_private  is_business_account  \
# 0       False                 True
# 1       False                 True
# 2       False                 True
# 3       False                 True
# 4       False                 True
# 5       False                 True
#
#                              business_category business_email  \
# 0                        Professional Services           None
# 1                       Creators & Celebrities           None
# 2                                  Restaurants           None
# 3                                   Publishers           None
# 4  Personal Goods & General Merchandise Stores           None
# 5                                 Auto Dealers           None
#
#         category_enum                             external_url
# 0   CREDIT_COUNSELING                   https://bit.ly/2ZovcS0
# 1            COMEDIAN        http://www.facebook.com/SoyElPayo
# 2  MEXICAN_RESTAURANT               http://www.lajarochita.mx/
# 3              SPORTS  https://www.facebook.com/WeAreFutbol11/
# 4     PRODUCT_SERVICE          http://www.nadyacabrera.com.ar/
# 5         MOTORCYCLES         https://linktr.ee/MOTOBANFIELDOK
